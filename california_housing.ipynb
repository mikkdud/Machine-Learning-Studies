# %% [markdown]
# 📊 Analiza danych mieszkaniowych z Kalifornii
# Ten notebook przedstawia wstępną analizę danych dotyczących nieruchomości w Kalifornii. Dane pochodzą z książki Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow autorstwa Auréliena Gérona.
#
# W projekcie wykonano:
#
# automatyczne pobranie i rozpakowanie zbioru danych,
#
# wczytanie danych do struktury pandas.DataFrame,
#
# podstawową eksplorację zbioru: podgląd struktury, typów danych, braków, liczności kategorii,
#
# przygotowanie środowiska analitycznego (import bibliotek i organizacja danych).
#
# Celem notebooka jest przygotowanie solidnej bazy pod dalszą analizę danych, wizualizację lub budowę modeli predykcyjnych.
#
# 🗂️ Zbiór danych
# Zbiór zawiera dane o dzielnicach w Kalifornii, a każda obserwacja reprezentuje jeden obszar geograficzny. Przykładowe kolumny:
#
# longitude i latitude – współrzędne geograficzne,
#
# housing_median_age – mediana wieku budynków,
#
# total_rooms, total_bedrooms – liczba pokoi i sypialni,
#
# population, households – populacja i liczba gospodarstw domowych,
#
# median_income – mediana dochodu w dzielnicy,
#
# median_house_value – mediana wartości domów,
#
# ocean_proximity – położenie względem oceanu.

# %%
# Importowanie wymaganych bibliotek
import os
import tarfile
import gzip
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split


# Tworzenie katalogu
os.makedirs('data', exist_ok=True)

# Pobranie pliku
url = 'https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.tgz'
file_path = 'data/housing.tgz'
urllib.request.urlretrieve(url, file_path)

# Rozpakowanie pliku .tgz
with tarfile.open(file_path, "r:gz") as tar:
    tar.extractall(path='data')

# Kompresowanie pliku CSV
with open('data/housing.csv', 'rb') as f_in:
    with gzip.open('data/housing.csv.gz', 'wb') as f_out:
        f_out.writelines(f_in)

# Usunięcie pliku .tgz
os.remove(file_path)


# Załadowanie danych
df = pd.read_csv('data/housing.csv.gz')

# Wyświetlenie pierwszych 4 rekordów
df.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY

# %% [markdown]
# Informacje o zbiorze

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df.ocean_proximity.describe()
# Out:
# count         20640
# unique            5
# top       <1H OCEAN
# freq           9136
# Name: ocean_proximity, dtype: object

# %% [markdown]
# Wizualizacja

# %%
df.hist(bins = 50, figsize=(20, 15))
plt.savefig("obraz1.png")

# %%
df.plot(kind='scatter', x='longitude', y='latitude', alpha = 0.1, figsize=(7,4))
plt.savefig("obraz2.png")

# %%
df.plot(colorbar=True, figsize=(7,3), kind="scatter", alpha = 0.4, x = 'longitude', y="latitude",
        label='population', c="median_house_value", cmap=plt.get_cmap("jet"), s=df["population"]/100)

plt.savefig("obraz3.png")

# %%
df.corr(numeric_only=True)["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
# musimy dodać argument numeric_only bo kolumna ocean_proximity jest opisowa, alternatywnie możnaby ją usunąć też po prostu za pomocą df.drop()
df.corr(numeric_only=True)["median_house_value"].sort_values(ascending=False).reset_index().rename(columns={"index":"atrybut", "median_house_value":"wspolczynnik_korelacji"}).to_csv("korelacja.csv", index=False)

# %%
import seaborn as sns

sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-835a85e3db9f> in <cell line: 0>()
#       1 import seaborn as sns
#       2
# ----> 3 sns.pairplot(df)
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

len(train_set), len(test_set)
# Out:
# (16512, 4128)

# %%
train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
#
#       ocean_proximity
# 14196      NEAR OCEAN
# 8267       NEAR OCEAN
# 17445      NEAR OCEAN
# 14265      NEAR OCEAN
# ...

# %%
test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0             NaN
# 3024     -119.46     35.14                30.0       2943.0             NaN
# 15663    -122.44     37.80                52.0       3830.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
# 9814     -121.93     36.62                34.0       2351.0             NaN
#
#        population  households  median_income  median_house_value  \
# 20046      1392.0       359.0         1.6812             47700.0
# 3024       1565.0       584.0         2.5313             45800.0
# 15663      1310.0       963.0         3.4801            500001.0
# 20484      1705.0       495.0         5.7376            218600.0
# 9814       1063.0       428.0         3.7250            278000.0
#
#       ocean_proximity
# 20046          INLAND
# 3024           INLAND
# 15663        NEAR BAY
# 20484       <1H OCEAN
# ...

# %%
test_set.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925351           -0.134397     0.068286
# latitude            -0.925351  1.000000            0.035154    -0.063542
# housing_median_age  -0.134397  0.035154            1.000000    -0.362596
# total_rooms          0.068286 -0.063542           -0.362596     1.000000
# total_bedrooms       0.096782 -0.095777           -0.319843     0.929952
# population           0.122507 -0.134640           -0.312528     0.854351
# households           0.079220 -0.098654           -0.303429     0.910780
# median_income       -0.006921 -0.093560           -0.107897     0.197011
# median_house_value  -0.044062 -0.149295            0.113585     0.134697
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.096782    0.122507    0.079220      -0.006921
# latitude                 -0.095777   -0.134640   -0.098654      -0.093560
# ...

# %%
train_set.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924485           -0.101818     0.038676
# latitude            -0.924485  1.000000            0.005296    -0.029224
# housing_median_age  -0.101818  0.005296            1.000000    -0.360922
# total_rooms          0.038676 -0.029224           -0.360922     1.000000
# total_bedrooms       0.063064 -0.059998           -0.320624     0.930489
# population           0.094276 -0.102499           -0.292283     0.857936
# households           0.049306 -0.064061           -0.302796     0.920482
# median_income       -0.017040 -0.076571           -0.121711     0.198268
# median_house_value  -0.046349 -0.142983            0.103706     0.133989
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063064    0.094276    0.049306      -0.017040
# latitude                 -0.059998   -0.102499   -0.064061      -0.076571
# ...
